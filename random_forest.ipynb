# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
np.random.seed(123)

# %%
dataset = pd.read_csv('C:\\Users\\KAVITA\\Project\\assam\\jorhat_as.csv')

# %%
#drop unwanted columns
dataset.drop(['state_code', 'stratum','district_code','PSU_ID',
       'ahs_house_unit', 'house_hold_no', 'date_survey','sl_no','usual_residance_Reason', 'identification_code',
               'date_of_birth', 'month_of_birth', 'year_of_birth','Weight_measured','Length_height_measured',
       'length_height_code','Haemoglobin_test',
       'Haemoglobin',], axis = 1, inplace = True)

# %%
print(dataset)
# Out:
#      rural_urban  test_salt_iodine            record_code_iodine  \
# 0          Rural                30  More than or equal to 15 PPM
# 1          Rural                30  More than or equal to 15 PPM
# 2          Rural                30  More than or equal to 15 PPM
# 3          Rural                30  More than or equal to 15 PPM
# 4          Rural                30  More than or equal to 15 PPM
# ...          ...               ...                           ...
# 8185       Rural                30  More than or equal to 15 PPM
# 8186       Rural                30  More than or equal to 15 PPM
# 8187       Urban                30  More than or equal to 15 PPM
# 8188       Urban                30  More than or equal to 15 PPM
# 8189       Urban                30  More than or equal to 15 PPM
#
#       record_code_iodine_reason     Sex usual_residance Age_Code  Age  \
# 0                           NaN    Male             YES     Year   22
# 1                           NaN  Female             YES     Year   14
# 2                           NaN    Male             YES     Year   60
# 3                           NaN  Female             YES     Year   48
# 4                           NaN    Male             YES     Year   17
# ...                         ...     ...             ...      ...  ...
# 8185                        NaN    Male             YES     Year   45
# 8186                        NaN  Female             YES     Year   40
# 8187                        NaN  Female             YES     Year   22
# 8188                        NaN  Female             YES     Year   18
# 8189                        NaN  Female             YES     Year    2
#
#       Weight_in_kg  Length_height_cm  ...  day_or_mn_for_breast_feeding_cd  \
# 0        41.200001         105.60000  ...                              NaN
# 1        27.900000         140.20000  ...                              NaN
# 2        51.599998         168.20000  ...                              NaN
# 3        37.900002         147.00000  ...                              NaN
# 4        41.000000         161.89999  ...                              NaN
# ...            ...               ...  ...                              ...
# 8185     44.500000         163.00000  ...                              NaN
# 8186     34.400002         143.39999  ...                              NaN
# 8187     43.900002         154.50000  ...                              NaN
# 8188     43.500000         147.50000  ...                              NaN
# 8189     11.400000          87.00000  ...                           Months
#
#       day_or_month_for_breast_feeding  water_month  ani_milk_month  \
# 0                                 NaN          NaN             NaN
# 1                                 NaN          NaN             NaN
# 2                                 NaN          NaN             NaN
# 3                                 NaN          NaN             NaN
# 4                                 NaN          NaN             NaN
# ...                               ...          ...             ...
# 8185                              NaN          NaN             NaN
# 8186                              NaN          NaN             NaN
# 8187                              NaN          NaN             NaN
# 8188                              NaN          NaN             NaN
# 8189                              6.0          7.0             8.0
#
#       semisolid_month_or_day  solid_month  vegetables_month_or_day  \
# 0                        NaN          NaN                      NaN
# 1                        NaN          NaN                      NaN
# 2                        NaN          NaN                      NaN
# 3                        NaN          NaN                      NaN
# 4                        NaN          NaN                      NaN
# ...                      ...          ...                      ...
# 8185                     NaN          NaN                      NaN
# 8186                     NaN          NaN                      NaN
# 8187                     NaN          NaN                      NaN
# 8188                     NaN          NaN                      NaN
# 8189                     9.0         11.0                     12.0
#
#      illness_type illness_duration  treatment_type
# 0             NaN              NaN             NaN
# 1             NaN              NaN             NaN
# 2             NaN              NaN             NaN
# 3             NaN              NaN             NaN
# 4             NaN              NaN             NaN
# ...           ...              ...             ...
# 8185          NaN              NaN             NaN
# 8186          NaN              NaN             NaN
# 8187          NaN              NaN             NaN
# 8188          NaN              NaN             NaN
# 8189   No illness              NaN             NaN
#
# [8190 rows x 35 columns]

# %%
label_encoder = LabelEncoder()
dataset.iloc[:,0] = label_encoder.fit_transform(dataset.iloc[:,0]).astype('float64')

# %%
dataset = dataset.fillna(0)

# %%
dataset.corr()
# Out:
#                                  rural_urban  test_salt_iodine  \
# rural_urban                         1.000000          0.168802
# test_salt_iodine                    0.168802          1.000000
# record_code_iodine_reason                NaN               NaN
# Age                                -0.011810          0.070122
# Weight_in_kg                        0.050868          0.099237
# Length_height_cm                    0.020305          0.053287
# Haemoglobin_level                  -0.010701          0.062884
# BP_systolic                         0.000430          0.062134
# BP_systolic_2_reading               0.000173          0.064773
# BP_Diastolic                       -0.000357          0.044553
# BP_Diastolic_2reading              -0.000880          0.047323
# Pulse_rate                         -0.000527          0.041163
# Pulse_rate_2_reading               -0.002833          0.044200
# fasting_blood_glucose_mg_dl         0.009264          0.055833
# duration_pregnanacy                 0.011229          0.016099
# day_or_month_for_breast_feeding     0.005818          0.005131
# water_month                         0.004593          0.004490
# ani_milk_month                      0.000907          0.005618
# semisolid_month_or_day              0.004954          0.003818
# solid_month                         0.004781          0.003609
# vegetables_month_or_day             0.004926          0.002436
# illness_duration                    0.045267          0.004555
#
#                                  record_code_iodine_reason       Age  \
# rural_urban                                            NaN -0.011810
# test_salt_iodine                                       NaN  0.070122
# record_code_iodine_reason                              NaN       NaN
# Age                                                    NaN  1.000000
# Weight_in_kg                                           NaN  0.314594
# Length_height_cm                                       NaN  0.139159
# Haemoglobin_level                                      NaN  0.058227
# BP_systolic                                            NaN  0.618366
# BP_systolic_2_reading                                  NaN  0.617162
# BP_Diastolic                                           NaN  0.587409
# BP_Diastolic_2reading                                  NaN  0.587169
# Pulse_rate                                             NaN  0.545305
# Pulse_rate_2_reading                                   NaN  0.547228
# fasting_blood_glucose_mg_dl                            NaN  0.572615
# duration_pregnanacy                                    NaN -0.040318
# day_or_month_for_breast_feeding                        NaN -0.278623
# water_month                                            NaN -0.261980
# ani_milk_month                                         NaN -0.260159
# semisolid_month_or_day                                 NaN -0.261841
# solid_month                                            NaN -0.260696
# vegetables_month_or_day                                NaN -0.259423
# illness_duration                                       NaN -0.127176
#
#                                  Weight_in_kg  Length_height_cm  \
# rural_urban                          0.050868          0.020305
# test_salt_iodine                     0.099237          0.053287
# record_code_iodine_reason                 NaN               NaN
# Age                                  0.314594          0.139159
# Weight_in_kg                         1.000000          0.860562
# Length_height_cm                     0.860562          1.000000
# Haemoglobin_level                    0.542030          0.635807
# BP_systolic                          0.751057          0.636220
# BP_systolic_2_reading                0.752128          0.638070
# BP_Diastolic                         0.757204          0.637881
# BP_Diastolic_2reading                0.757995          0.640747
# Pulse_rate                           0.717880          0.630503
# Pulse_rate_2_reading                 0.722132          0.634246
# fasting_blood_glucose_mg_dl          0.715023          0.618100
# duration_pregnanacy                  0.059846          0.071288
# day_or_month_for_breast_feeding     -0.238023         -0.171601
# water_month                         -0.217436         -0.153859
# ani_milk_month                      -0.215784         -0.152863
# semisolid_month_or_day              -0.216059         -0.152794
# solid_month                         -0.214388         -0.151452
# vegetables_month_or_day             -0.212743         -0.150137
# illness_duration                    -0.108853         -0.076118
#
#                                  Haemoglobin_level  BP_systolic  \
# rural_urban                              -0.010701     0.000430
# test_salt_iodine                          0.062884     0.062134
# record_code_iodine_reason                      NaN          NaN
# Age                                       0.058227     0.618366
# Weight_in_kg                              0.542030     0.751057
# Length_height_cm                          0.635807     0.636220
# Haemoglobin_level                         1.000000     0.395300
# BP_systolic                               0.395300     1.000000
# BP_systolic_2_reading                     0.396418     0.998118
# BP_Diastolic                              0.395739     0.981092
# BP_Diastolic_2reading                     0.398033     0.981608
# Pulse_rate                                0.381428     0.939835
# Pulse_rate_2_reading                      0.385409     0.943245
# fasting_blood_glucose_mg_dl               0.400833     0.907943
# duration_pregnanacy                       0.028552     0.091032
# day_or_month_for_breast_feeding          -0.082627    -0.228324
# water_month                              -0.053258    -0.213130
# ani_milk_month                           -0.053844    -0.211724
# semisolid_month_or_day                   -0.052222    -0.212426
# solid_month                              -0.049279    -0.211014
# vegetables_month_or_day                  -0.045848    -0.209297
# illness_duration                         -0.018804    -0.106201
#
#                                  BP_systolic_2_reading  BP_Diastolic  ...  \
# rural_urban                                   0.000173     -0.000357  ...
# test_salt_iodine                              0.064773      0.044553  ...
# record_code_iodine_reason                          NaN           NaN  ...
# Age                                           0.617162      0.587409  ...
# Weight_in_kg                                  0.752128      0.757204  ...
# Length_height_cm                              0.638070      0.637881  ...
# Haemoglobin_level                             0.396418      0.395739  ...
# BP_systolic                                   0.998118      0.981092  ...
# BP_systolic_2_reading                         1.000000      0.980733  ...
# BP_Diastolic                                  0.980733      1.000000  ...
# BP_Diastolic_2reading                         0.982619      0.998133  ...
# Pulse_rate                                    0.940560      0.947737  ...
# Pulse_rate_2_reading                          0.944870      0.950126  ...
# fasting_blood_glucose_mg_dl                   0.908544      0.901410  ...
# duration_pregnanacy                           0.092470      0.092453  ...
# day_or_month_for_breast_feeding              -0.228596     -0.227967  ...
# water_month                                  -0.213383     -0.212797  ...
# ani_milk_month                               -0.211976     -0.211393  ...
# semisolid_month_or_day                       -0.212679     -0.212094  ...
# solid_month                                  -0.211264     -0.210684  ...
# vegetables_month_or_day                      -0.209545     -0.208969  ...
# illness_duration                             -0.106328     -0.106035  ...
#
#                                  Pulse_rate_2_reading  \
# rural_urban                                 -0.002833
# test_salt_iodine                             0.044200
# record_code_iodine_reason                         NaN
# Age                                          0.547228
# Weight_in_kg                                 0.722132
# Length_height_cm                             0.634246
# Haemoglobin_level                            0.385409
# BP_systolic                                  0.943245
# BP_systolic_2_reading                        0.944870
# BP_Diastolic                                 0.950126
# BP_Diastolic_2reading                        0.953301
# Pulse_rate                                   0.998471
# Pulse_rate_2_reading                         1.000000
# fasting_blood_glucose_mg_dl                  0.902476
# duration_pregnanacy                          0.134945
# day_or_month_for_breast_feeding             -0.229716
# water_month                                 -0.214429
# ani_milk_month                              -0.213014
# semisolid_month_or_day                      -0.213721
# solid_month                                 -0.212300
# vegetables_month_or_day                     -0.210572
# illness_duration                            -0.106849
#
#                                  fasting_blood_glucose_mg_dl  \
# rural_urban                                         0.009264
# test_salt_iodine                                    0.055833
# record_code_iodine_reason                                NaN
# Age                                                 0.572615
# Weight_in_kg                                        0.715023
# Length_height_cm                                    0.618100
# Haemoglobin_level                                   0.400833
# BP_systolic                                         0.907943
# BP_systolic_2_reading                               0.908544
# BP_Diastolic                                        0.901410
# BP_Diastolic_2reading                               0.903869
# Pulse_rate                                          0.899655
# Pulse_rate_2_reading                                0.902476
# fasting_blood_glucose_mg_dl                         1.000000
# duration_pregnanacy                                 0.104465
# day_or_month_for_breast_feeding                    -0.221206
# water_month                                        -0.206485
# ani_milk_month                                     -0.205123
# semisolid_month_or_day                             -0.205803
# solid_month                                        -0.204435
# vegetables_month_or_day                            -0.202771
# illness_duration                                   -0.102890
#
#                                  duration_pregnanacy  \
# rural_urban                                 0.011229
# test_salt_iodine                            0.016099
# record_code_iodine_reason                        NaN
# Age                                        -0.040318
# Weight_in_kg                                0.059846
# Length_height_cm                            0.071288
# Haemoglobin_level                           0.028552
# BP_systolic                                 0.091032
# BP_systolic_2_reading                       0.092470
# BP_Diastolic                                0.092453
# BP_Diastolic_2reading                       0.095705
# Pulse_rate                                  0.136020
# Pulse_rate_2_reading                        0.134945
# fasting_blood_glucose_mg_dl                 0.104465
# duration_pregnanacy                         1.000000
# day_or_month_for_breast_feeding            -0.030940
# water_month                                -0.028881
# ani_milk_month                             -0.028690
# semisolid_month_or_day                     -0.028786
# solid_month                                -0.028594
# vegetables_month_or_day                    -0.028361
# illness_duration                           -0.014391
#
#                                  day_or_month_for_breast_feeding  water_month  \
# rural_urban                                             0.005818     0.004593
# test_salt_iodine                                        0.005131     0.004490
# record_code_iodine_reason                                    NaN          NaN
# Age                                                    -0.278623    -0.261980
# Weight_in_kg                                           -0.238023    -0.217436
# Length_height_cm                                       -0.171601    -0.153859
# Haemoglobin_level                                      -0.082627    -0.053258
# BP_systolic                                            -0.228324    -0.213130
# BP_systolic_2_reading                                  -0.228596    -0.213383
# BP_Diastolic                                           -0.227967    -0.212797
# BP_Diastolic_2reading                                  -0.228798    -0.213573
# Pulse_rate                                             -0.228881    -0.213650
# Pulse_rate_2_reading                                   -0.229716    -0.214429
# fasting_blood_glucose_mg_dl                            -0.221206    -0.206485
# duration_pregnanacy                                    -0.030940    -0.028881
# day_or_month_for_breast_feeding                         1.000000     0.954035
# water_month                                             0.954035     1.000000
# ani_milk_month                                          0.943995     0.990000
# semisolid_month_or_day                                  0.945615     0.991870
# solid_month                                             0.936990     0.983032
# vegetables_month_or_day                                 0.927031     0.972868
# illness_duration                                        0.294132     0.300090
#
#                                  ani_milk_month  semisolid_month_or_day  \
# rural_urban                            0.000907                0.004954
# test_salt_iodine                       0.005618                0.003818
# record_code_iodine_reason                   NaN                     NaN
# Age                                   -0.260159               -0.261841
# Weight_in_kg                          -0.215784               -0.216059
# Length_height_cm                      -0.152863               -0.152794
# Haemoglobin_level                     -0.053844               -0.052222
# BP_systolic                           -0.211724               -0.212426
# BP_systolic_2_reading                 -0.211976               -0.212679
# BP_Diastolic                          -0.211393               -0.212094
# BP_Diastolic_2reading                 -0.212164               -0.212868
# Pulse_rate                            -0.212240               -0.212944
# Pulse_rate_2_reading                  -0.213014               -0.213721
# fasting_blood_glucose_mg_dl           -0.205123               -0.205803
# duration_pregnanacy                   -0.028690               -0.028786
# day_or_month_for_breast_feeding        0.943995                0.945615
# water_month                            0.990000                0.991870
# ani_milk_month                         1.000000                0.986131
# semisolid_month_or_day                 0.986131                1.000000
# solid_month                            0.979688                0.993928
# vegetables_month_or_day                0.970858                0.985028
# illness_duration                       0.301121                0.298938
#
#                                  solid_month  vegetables_month_or_day  \
# rural_urban                         0.004781                 0.004926
# test_salt_iodine                    0.003609                 0.002436
# record_code_iodine_reason                NaN                      NaN
# Age                                -0.260696                -0.259423
# Weight_in_kg                       -0.214388                -0.212743
# Length_height_cm                   -0.151452                -0.150137
# Haemoglobin_level                  -0.049279                -0.045848
# BP_systolic                        -0.211014                -0.209297
# BP_systolic_2_reading              -0.211264                -0.209545
# BP_Diastolic                       -0.210684                -0.208969
# BP_Diastolic_2reading              -0.211452                -0.209731
# Pulse_rate                         -0.211528                -0.209807
# Pulse_rate_2_reading               -0.212300                -0.210572
# fasting_blood_glucose_mg_dl        -0.204435                -0.202771
# duration_pregnanacy                -0.028594                -0.028361
# day_or_month_for_breast_feeding     0.936990                 0.927031
# water_month                         0.983032                 0.972868
# ani_milk_month                      0.979688                 0.970858
# semisolid_month_or_day              0.993928                 0.985028
# solid_month                         1.000000                 0.991264
# vegetables_month_or_day             0.991264                 1.000000
# illness_duration                    0.301941                 0.305090
#
#                                  illness_duration
# rural_urban                              0.045267
# test_salt_iodine                         0.004555
# record_code_iodine_reason                     NaN
# Age                                     -0.127176
# Weight_in_kg                            -0.108853
# Length_height_cm                        -0.076118
# Haemoglobin_level                       -0.018804
# BP_systolic                             -0.106201
# BP_systolic_2_reading                   -0.106328
# BP_Diastolic                            -0.106035
# BP_Diastolic_2reading                   -0.106422
# Pulse_rate                              -0.106460
# Pulse_rate_2_reading                    -0.106849
# fasting_blood_glucose_mg_dl             -0.102890
# duration_pregnanacy                     -0.014391
# day_or_month_for_breast_feeding          0.294132
# water_month                              0.300090
# ani_milk_month                           0.301121
# semisolid_month_or_day                   0.298938
# solid_month                              0.301941
# vegetables_month_or_day                  0.305090
# illness_duration                         1.000000
#
# [22 rows x 22 columns]

# %%
X = dataset[['rural_urban', 'test_salt_iodine', 'record_code_iodine','record_code_iodine_reason', 'Sex', 'usual_residance', 'Age_Code',
       'Age', 'Weight_in_kg', 'Length_height_cm', 'Haemoglobin_level',
       'BP_systolic', 'BP_systolic_2_reading', 'BP_Diastolic',
       'BP_Diastolic_2reading', 'Pulse_rate', 'Pulse_rate_2_reading',
       'Diabetes_test', 'fasting_blood_glucose', 'fasting_blood_glucose_mg_dl',
       'Marital_status', 'gauna_perfor_not_perfor', 'duration_pregnanacy',
       'first_breast_feeding', 'is_cur_breast_feeding',
       'day_or_mn_for_breast_feeding_cd', 'day_or_month_for_breast_feeding',
       'water_month', 'ani_milk_month', 'semisolid_month_or_day',
       'solid_month', 'vegetables_month_or_day', 'illness_type',
       'illness_duration', 'treatment_type']]
y = dataset['Haemoglobin_level']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-7950e78513c5> in <module>
#       5
#       6 #Train the model using the training sets y_pred=clf.predict(X_test)
# ----> 7 clf.fit(X_train,y_train)
#       8
#       9 y_pred=clf.predict(X_test)
#
# D:\Anaconda\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     293         """
#     294         # Validate or convert input data
# --> 295         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     296         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     297         if sample_weight is not None:
#
# D:\Anaconda\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     529                     array = array.astype(dtype, casting="unsafe", copy=False)
#     530                 else:
# --> 531                     array = np.asarray(array, order=order, dtype=dtype)
#     532             except ComplexWarning:
#     533                 raise ValueError("Complex data not supported\n"
#
# D:\Anaconda\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: 'More than or equal to 15 PPM'
