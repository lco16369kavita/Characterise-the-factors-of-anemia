# %%
import os
import glob
import pandas as pd
os.chdir("C:\\Users\\KAVITA\\project\\data")

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
df=pd.read_csv("C:\\Users\\KAVITA\\project\\data\\combined_csv.csv")
df
# Out:
# E:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (10,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             state_code district_code rural_urban           stratum   PSU_ID  \
# 0                ASSAM       BARPETA       Rural  population>=2000  1104095
# 1                ASSAM       BARPETA       Rural  population>=2000  1104307
# 2                ASSAM       BARPETA       Rural  population>=2000  1104275
# 3                ASSAM       BARPETA       Rural  population>=2000  1104520
# 4                ASSAM       BARPETA       Rural  population>=2000  1104276
# ...                ...           ...         ...               ...      ...
# 1889312  UTTAR PRADESH         UNNAO       Urban             Urban  2518990
# 1889313  UTTAR PRADESH         UNNAO       Urban             Urban  2518345
# ...

# %%
df.shape
# Out:
# (1889317, 53)

# %%
df.isnull().sum()
# Out:
# state_code                               0
# district_code                            0
# rural_urban                              0
# stratum                                  0
# PSU_ID                                   0
# ahs_house_unit                           0
# house_hold_no                            0
# date_survey                             95
# test_salt_iodine                         0
# record_code_iodine                       0
# record_code_iodine_reason          1882919
# sl_no                                    0
# Sex                                      0
# usual_residance                          0
# usual_residance_Reason             1805636
# identification_code                    432
# Age_Code                                 0
# Age                                     89
# date_of_birth                            0
# month_of_birth                           0
# year_of_birth                            0
# Weight_measured                     230117
# ...

# %%
df.head()
# Out:
#   state_code district_code rural_urban           stratum   PSU_ID  \
# 0      ASSAM       BARPETA       Rural  population>=2000  1104095
# 1      ASSAM       BARPETA       Rural  population>=2000  1104307
# 2      ASSAM       BARPETA       Rural  population>=2000  1104275
# 3      ASSAM       BARPETA       Rural  population>=2000  1104520
# 4      ASSAM       BARPETA       Rural  population>=2000  1104276
#
#    ahs_house_unit  house_hold_no date_survey  test_salt_iodine  \
# 0              97              2    26-11-14                 7
# 1              97              2    26-11-14                 7
# 2             103              1    26-11-14                 7
# 3             103              1    26-11-14                 7
# 4             103              1    26-11-14                 7
#
#   record_code_iodine  ... day_or_mn_for_breast_feeding_cd  \
# 0   Less than 15 PPM  ...                             NaN
# 1   Less than 15 PPM  ...                             NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1889317 entries, 0 to 1889316
# Data columns (total 40 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   state_code                       object
#  1   district_code                    object
#  2   rural_urban                      object
#  3   stratum                          object
#  4   test_salt_iodine                 int64
#  5   record_code_iodine               object
#  6   record_code_iodine_reason        object
#  7   Sex                              object
#  8   usual_residance                  object
#  9   usual_residance_Reason           object
#  10  identification_code              float64
#  11  Age_Code                         object
#  12  Age                              float64
#  13  Weight_in_kg                     float64
#  14  Length_height_cm                 float64
#  15  Haemoglobin_level                float64
# ...

# %%
df['state_code'].value_counts()
# Out:
# UTTAR PRADESH     490546
# BIHAR             284464
# MADHYA PRADESH    261137
# RAJASTHAN         212094
# ODISHA            198174
# ASSAM             142838
# JHARKHAND         127807
# CHHATTISGARH      104915
# UTTARAKHAND        67342
# Name: state_code, dtype: int64

# %%
df.describe()
# Out:
#              PSU_ID  ahs_house_unit  house_hold_no  test_salt_iodine  \
# count  1.889317e+06    1.889317e+06   1.889317e+06      1.889317e+06
# mean   1.944687e+06    1.673226e+02   1.434086e+00      2.224802e+01
# std    5.454471e+05    1.537753e+02   1.501963e+00      1.020840e+01
# min    1.000001e+06   -5.600000e+01   0.000000e+00      0.000000e+00
# 25%    1.472330e+06    6.000000e+01   1.000000e+00      1.500000e+01
# 50%    1.944659e+06    1.320000e+02   1.000000e+00      3.000000e+01
# 75%    2.416988e+06    2.390000e+02   1.000000e+00      3.000000e+01
# max    2.891239e+06    9.150000e+03   4.250000e+02      6.700000e+01
#
#               sl_no  identification_code           Age  date_of_birth  \
# count  1.889317e+06         1.888885e+06  1.889228e+06   1.889317e+06
# mean   3.535152e+00         1.105301e+03  2.869601e+01   9.846871e+00
# std    1.117982e+01         2.016706e+03  1.980412e+01   7.998741e+00
# ...

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(20,15))
plt.show()

# %%
df['Sex'].value_counts()
# Out:
# Male      961394
# Female    927923
# Name: Sex, dtype: int64

# %%
df.drop(['PSU_ID','ahs_house_unit', 'house_hold_no', 'date_survey','sl_no','date_of_birth', 'month_of_birth', 'year_of_birth','Weight_measured','Length_height_measured',
       'length_height_code','Haemoglobin_test',
       'Haemoglobin',], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1889317 entries, 0 to 1889316
# Data columns (total 40 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   state_code                       object
#  1   district_code                    object
#  2   rural_urban                      object
#  3   stratum                          object
#  4   test_salt_iodine                 int64
#  5   record_code_iodine               object
#  6   record_code_iodine_reason        object
#  7   Sex                              object
#  8   usual_residance                  object
#  9   usual_residance_Reason           object
#  10  identification_code              float64
#  11  Age_Code                         object
#  12  Age                              float64
#  13  Weight_in_kg                     float64
#  14  Length_height_cm                 float64
#  15  Haemoglobin_level                float64
# ...
